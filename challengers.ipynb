# %%
## TWO SUM

class Solution:
    def ts(self, nums):
        target = 12
        N = len(nums)
        array = []
        for z in range(0, N):
            for i in range(0, N):
                if((nums[z] + nums[i]) == target) and (z != i):
                    A = nums[z]
                    B = nums[i]
                    array.extend([z,i])
                    return array
sol = Solution()
print(sol.ts([4,2,10]))
# Out:
# [1, 2]
